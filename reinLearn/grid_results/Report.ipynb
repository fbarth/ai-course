# %% [markdown]
# # Resultados da execução de Julho/2020

# %%
import pandas as pd
df = pd.read_csv("results_frozen_lake.csv")

# %%
df.head()
# Out:
#    alpha  gamma  epsilon  episodes  rewards
# 0    1.0   0.99      0.9     10000        4
# 1    1.0   0.99      0.9     50000        0
# 2    1.0   0.99      0.9    100000        0
# 3    1.0   0.99      0.8     10000       10
# 4    1.0   0.99      0.8     50000        0

# %%
df.shape
# Out:
# (864, 5)

# %%
df.sort_values(by=['rewards'], ascending=False)
# Out:
#      alpha  gamma  epsilon  episodes  rewards
# 400   0.80   0.95      0.8     50000       91
# 397   0.80   0.95      0.9     50000       90
# 779   0.20   0.99      0.5    100000       89
# 120   0.95   0.90      0.9     10000       89
# 773   0.20   0.99      0.8    100000       89
# ..     ...    ...      ...       ...      ...
# 88    1.00   0.30      0.8     50000        0
# 89    1.00   0.30      0.8    100000        0
# 91    1.00   0.30      0.7     50000        0
# 92    1.00   0.30      0.7    100000        0
# 94    1.00   0.30      0.5     50000        0
#
# [864 rows x 5 columns]

# %%
df.describe()
# Out:
#             alpha       gamma     epsilon       episodes     rewards
# count  864.000000  864.000000  864.000000     864.000000  864.000000
# mean     0.688889    0.755000    0.725000   53333.333333   36.083333
# std      0.273794    0.223008    0.147988   36839.195208   29.447559
# min      0.200000    0.300000    0.500000   10000.000000    0.000000
# 25%      0.500000    0.687500    0.650000   10000.000000    9.000000
# 50%      0.800000    0.825000    0.750000   50000.000000   30.000000
# 75%      0.900000    0.912500    0.825000  100000.000000   63.000000
# max      1.000000    0.990000    0.900000  100000.000000   91.000000

# %%
df.corr()
# Out:
#                  alpha         gamma       epsilon      episodes   rewards
# alpha     1.000000e+00 -7.479680e-17  7.937607e-19 -1.086646e-17 -0.157279
# gamma    -7.479680e-17  1.000000e+00 -7.114041e-17  1.847231e-17  0.507427
# epsilon   7.937607e-19 -7.114041e-17  1.000000e+00  0.000000e+00  0.010795
# episodes -1.086646e-17  1.847231e-17  0.000000e+00  1.000000e+00  0.323295
# rewards  -1.572794e-01  5.074271e-01  1.079544e-02  3.232951e-01  1.000000

# %%
df.boxplot(column='rewards', by=['gamma','episodes'], figsize=(15,10), vert=False)
# Out:
# <AxesSubplot:title={'center':'rewards'}, xlabel='[gamma, episodes]'>

# %%
df.boxplot(column='rewards', by=['gamma','alpha'], figsize=(15,20), vert=False)
# Out:
# <AxesSubplot:title={'center':'rewards'}, xlabel='[gamma, alpha]'>

# %%
df.boxplot(column='rewards', by=['gamma','alpha','episodes'], figsize=(15,50), vert=False)
# Out:
# <AxesSubplot:title={'center':'rewards'}, xlabel='[gamma, alpha, episodes]'>

# %%
best = df[(df['gamma'] > 0.95) & (df['alpha'] <= 0.3)]

# %%
best
# Out:
#      alpha  gamma  epsilon  episodes  rewards
# 672    0.3   0.99      0.9     10000       86
# 673    0.3   0.99      0.9     50000       82
# 674    0.3   0.99      0.9    100000       85
# 675    0.3   0.99      0.8     10000       85
# 676    0.3   0.99      0.8     50000       57
# 677    0.3   0.99      0.8    100000       81
# 678    0.3   0.99      0.7     10000       85
# 679    0.3   0.99      0.7     50000       88
# 680    0.3   0.99      0.7    100000       82
# 681    0.3   0.99      0.5     10000       72
# 682    0.3   0.99      0.5     50000       82
# 683    0.3   0.99      0.5    100000       88
# 768    0.2   0.99      0.9     10000       83
# 769    0.2   0.99      0.9     50000       84
# 770    0.2   0.99      0.9    100000       82
# 771    0.2   0.99      0.8     10000       79
# 772    0.2   0.99      0.8     50000       84
# 773    0.2   0.99      0.8    100000       89
# 774    0.2   0.99      0.7     10000       79
# ...

# %% [markdown]
# # Conclusão
#
# Os melhores resultados são quando temos um gamma de 0.99 e um alpha baixo (abaixo de 0.3) - não foi avaliado alpha de 0.1. Os valores de epsilon e episodes não parecem impactar e o rewards. Lembrando que os valores de episodes testados foram 10, 50 e 100 mil.
#
# Desta forma, sugere-se os seguintes hiperparâmetros:
# * alpha = 0.2
# * gamma = 0.99
# * epsilon = 0.8
# * episodes = 100000

# %% [markdown]
# ## Nota
#
# Faz sentido executar uma regressão linear onde y = rewards e os demais são X. Encontrar os coeficientes e então calcular o valor de cada variável levando-se em consideração rewards = 100 e os coeficientes encontrados?

# %% [markdown]
# # Resultados da execução de setembro / 2020

# %%
df2 = pd.read_csv("finalResults_FrozenLake_final.csv", sep=';', header=None)
df2.head()
# Out:
#     0    1     2    3         4     5   6
# 0 NaN  0.1  0.95  0.7   10000.0  77.0 NaN
# 1 NaN  0.1  0.95  0.7  100000.0  79.0 NaN
# 2 NaN  0.1  0.95  0.8   10000.0  46.0 NaN
# 3 NaN  0.1  0.95  0.8  100000.0  74.0 NaN
# 4 NaN  0.1  0.99  0.7   10000.0  86.0 NaN

# %%
df2.shape
# Out:
# (1744, 7)

# %%
df2 = df2.iloc[:,[1,2,3,4,5]]

# %%
df2.head()
# Out:
#      1     2    3         4     5
# 0  0.1  0.95  0.7   10000.0  77.0
# 1  0.1  0.95  0.7  100000.0  79.0
# 2  0.1  0.95  0.8   10000.0  46.0
# 3  0.1  0.95  0.8  100000.0  74.0
# 4  0.1  0.99  0.7   10000.0  86.0

# %%
df2.columns=['alpha','gamma','epsilon','episodes','rewards']
df2.head()
# Out:
#    alpha  gamma  epsilon  episodes  rewards
# 0    0.1   0.95      0.7   10000.0     77.0
# 1    0.1   0.95      0.7  100000.0     79.0
# 2    0.1   0.95      0.8   10000.0     46.0
# 3    0.1   0.95      0.8  100000.0     74.0
# 4    0.1   0.99      0.7   10000.0     86.0

# %%
df2 = df2.drop_duplicates()
df2.shape
# Out:
# (872, 5)

# %%
df2['rewards'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

df3 = df2[df2['episodes'] == 100000]

fig = plt.figure(figsize=(10,7))
ax = fig.gca(projection='3d')
ax.plot_trisurf(df3['alpha'], df3['gamma'], df3['rewards'], cmap=plt.cm.viridis)
ax.set_title('100k episodes')
ax.set_xlabel('alpha')
ax.set_ylabel('gamma')
ax.set_zlabel('rewards')
ax.set_zlim(0, 100)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

df3 = df2[df2['episodes'] == 50000]

fig = plt.figure(figsize=(10,7))
ax = fig.gca(projection='3d')
ax.plot_trisurf(df3['alpha'], df3['gamma'], df3['rewards'], cmap=plt.cm.viridis)
ax.set_title('50k episodes')
ax.set_xlabel('alpha')
ax.set_ylabel('gamma')
ax.set_zlabel('rewards')
ax.set_zlim(0, 100)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

df3 = df2[df2['episodes'] == 10000]

fig = plt.figure(figsize=(10,7))
ax = fig.gca(projection='3d')
ax.plot_trisurf(df3['alpha'], df3['gamma'], df3['rewards'], cmap=plt.cm.viridis)
ax.set_title('10k episodes')
ax.set_xlabel('alpha')
ax.set_ylabel('gamma')
ax.set_zlabel('rewards')
ax.set_zlim(0, 100)
plt.show()

# %%
df2.sort_values(by='rewards', ascending=False).head(20)
# Out:
#      alpha  gamma  epsilon  episodes  rewards
# 264   0.50   0.95      0.7  100000.0     94.0
# 262   0.50   0.95      0.5   50000.0     90.0
# 553   0.80   0.95      0.7   50000.0     90.0
# 763   0.90   0.99      0.9   50000.0     90.0
# 459   0.85   0.95      0.8  100000.0     90.0
# 762   0.90   0.99      0.9  100000.0     89.0
# 555   0.80   0.95      0.8  100000.0     89.0
# 281   0.50   0.99      0.9   10000.0     88.0
# 484   0.85   0.90      0.8   50000.0     88.0
# 378   0.70   0.99      0.9  100000.0     88.0
# 765   0.90   0.90      0.5  100000.0     88.0
# 270   0.50   0.95      0.9  100000.0     87.0
# 390   0.70   0.90      0.9  100000.0     87.0
# 372   0.70   0.99      0.7  100000.0     87.0
# 487   0.85   0.90      0.9   50000.0     87.0
# 342   0.70   0.85      0.9  100000.0     87.0
# 177   0.30   0.99      0.5  100000.0     86.0
# 181   0.30   0.99      0.7   50000.0     86.0
# 667   0.95   0.99      0.9   50000.0     86.0
# ...
